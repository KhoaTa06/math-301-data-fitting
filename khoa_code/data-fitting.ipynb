# %%
import pandas as pd
import seaborn as sns
from matplotlib import pyplot as plt

# %%
dataFilepath = "Group_1_Data.txt"
data = pd.read_csv(dataFilepath)
data.columns
data.drop('y)', axis=1, inplace=True)
data.columns=["x", "y", "f(x,y)"]
data
# Out:
#            x    y  f(x,y)
# 0     0.0000  0.0  0.0223
# 1     0.0505  0.0 -0.0012
# 2     0.1010  0.0  0.0437
# 3     0.1515  0.0 -0.0097
# 4     0.2020  0.0 -0.0376
# ...      ...  ...     ...
# 9995  4.7980  5.0  5.5542
# 9996  4.8485  5.0  5.4574
# 9997  4.8990  5.0  5.6016
# 9998  4.9495  5.0  5.5779
# 9999  5.0000  5.0  5.6978
#
# [10000 rows x 3 columns]

# %%
sns.scatterplot(data=data, x='x', y='y')
# Out:
# <Axes: xlabel='x', ylabel='y'>

# %%
fig = plt.figure()
ax = plt.axes(projection='3d')
ax.plot(data['x'], data['y'], data['f(x,y)'])
